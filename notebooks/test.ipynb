# %%
import sys
import os
sys.path.append(os.pardir)

# %%
import pandas as pd

# %%
from extract import get_weather_client, fetch_weather

# %%
from extract import get_load_client, fetch_load

# %%
weather_client = get_weather_client()

# %%
weather_client

# %%
weather_df = fetch_weather(weather_client)

# %%
weather_df.head()
# Out:
#                        date  temperature
# 0 2025-01-01 00:00:00+00:00      -0.1385
# 1 2025-01-01 01:00:00+00:00      -0.1385
# 2 2025-01-01 02:00:00+00:00      -0.1385
# 3 2025-01-01 03:00:00+00:00      -0.3885
# 4 2025-01-01 04:00:00+00:00      -0.2885

# %%
weather_df.size
# Out:
# 1536

# %%
load_client = get_load_client()

# %%
load_client
# Out:
# GridStatusClient(host=https://api.gridstatus.io/v1)

# %%
load_df = fetch_load(load_client)
# Out:
# 2026-06-04 17:47:31 - INFO - Fetching Page 1...
# 2026-06-04 17:47:31 - INFO - GET https://api.gridstatus.io/v1/datasets/spp_load_hourly/query
# 2026-06-04 17:47:31 - INFO - Params: {'start_time': Timestamp('2025-01-01 00:00:00'), 'end_time': Timestamp('2025-01-08 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': 100, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': None, 'cursor': '', 'filter_column': 'balancing_area_name', 'filter_value': 'SPP', 'filter_operator': '=', 'columns': 'interval_start_utc,balancing_area_name,control_zone_name,forecast_area_type,load', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# Fetching 2025-01-01 to 2025-01-08...
# 2026-06-04 17:47:32 - INFO - Done in 1.63 seconds.
# 2026-06-04 17:47:32 - INFO - Total rows: 100/100 (100.0% of limit)
# 2026-06-04 17:47:32 - INFO - Total number of rows: 100
# 2026-06-04 17:47:32 - INFO - Fetching Page 1...
# 2026-06-04 17:47:32 - INFO - GET https://api.gridstatus.io/v1/datasets/spp_load_hourly/query
# 2026-06-04 17:47:32 - INFO - Params: {'start_time': Timestamp('2025-01-08 00:00:00'), 'end_time': Timestamp('2025-01-15 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': 100, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': None, 'cursor': '', 'filter_column': 'balancing_area_name', 'filter_value': 'SPP', 'filter_operator': '=', 'columns': 'interval_start_utc,balancing_area_name,control_zone_name,forecast_area_type,load', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# Fetching 2025-01-08 to 2025-01-15...
# 2026-06-04 17:47:33 - INFO - Done in 0.41 seconds.
# 2026-06-04 17:47:33 - INFO - Total rows: 100/100 (100.0% of limit)
# 2026-06-04 17:47:33 - INFO - Total number of rows: 100
# 2026-06-04 17:47:33 - INFO - Fetching Page 1...
# 2026-06-04 17:47:33 - INFO - GET https://api.gridstatus.io/v1/datasets/spp_load_hourly/query
# 2026-06-04 17:47:33 - INFO - Params: {'start_time': Timestamp('2025-01-15 00:00:00'), 'end_time': Timestamp('2025-01-22 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': 100, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': None, 'cursor': '', 'filter_column': 'balancing_area_name', 'filter_value': 'SPP', 'filter_operator': '=', 'columns': 'interval_start_utc,balancing_area_name,control_zone_name,forecast_area_type,load', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# Fetching 2025-01-15 to 2025-01-22...
# 2026-06-04 17:47:33 - INFO - Too Many Requests. Limit: 1 per 1 second.. Retrying in 1 seconds. Retry 1 of 3.
# 2026-06-04 17:47:35 - INFO - Done in 1.74 seconds.
# 2026-06-04 17:47:35 - INFO - Total rows: 100/100 (100.0% of limit)
# 2026-06-04 17:47:35 - INFO - Total number of rows: 100
# 2026-06-04 17:47:35 - INFO - Fetching Page 1...
# 2026-06-04 17:47:35 - INFO - GET https://api.gridstatus.io/v1/datasets/spp_load_hourly/query
# 2026-06-04 17:47:35 - INFO - Params: {'start_time': Timestamp('2025-01-22 00:00:00'), 'end_time': Timestamp('2025-01-29 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': 100, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': None, 'cursor': '', 'filter_column': 'balancing_area_name', 'filter_value': 'SPP', 'filter_operator': '=', 'columns': 'interval_start_utc,balancing_area_name,control_zone_name,forecast_area_type,load', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# Fetching 2025-01-22 to 2025-01-29...
# 2026-06-04 17:47:35 - INFO - Too Many Requests. Limit: 1 per 1 second.. Retrying in 1 seconds. Retry 1 of 3.
# 2026-06-04 17:47:36 - INFO - Done in 1.72 seconds.
# 2026-06-04 17:47:36 - INFO - Total rows: 100/100 (100.0% of limit)
# 2026-06-04 17:47:36 - INFO - Total number of rows: 100
# 2026-06-04 17:47:36 - INFO - Fetching Page 1...
# 2026-06-04 17:47:36 - INFO - GET https://api.gridstatus.io/v1/datasets/spp_load_hourly/query
# 2026-06-04 17:47:36 - INFO - Params: {'start_time': Timestamp('2025-01-29 00:00:00'), 'end_time': Timestamp('2025-02-01 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': 100, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': None, 'cursor': '', 'filter_column': 'balancing_area_name', 'filter_value': 'SPP', 'filter_operator': '=', 'columns': 'interval_start_utc,balancing_area_name,control_zone_name,forecast_area_type,load', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# Fetching 2025-01-29 to 2025-02-01...
# 2026-06-04 17:47:37 - INFO - Too Many Requests. Limit: 1 per 1 second.. Retrying in 1 seconds. Retry 1 of 3.
# 2026-06-04 17:47:39 - INFO - Done in 2.97 seconds.
# 2026-06-04 17:47:39 - INFO - Total rows: 100/100 (100.0% of limit)
# 2026-06-04 17:47:39 - INFO - Total number of rows: 100
