# %%
import sys
import os
sys.path.append(os.pardir)

# %%
import pandas as pd
from datetime import datetime, timedelta

# %%
from extract import get_weather_client, fetch_weather, fetch_weather_batches

# %%
from extract import get_load_client, fetch_load

# %%
#two weeks
start_date = datetime(2025, 1, 1)
end_date = datetime(2025, 1, 14)

# %% [markdown]
# ### Test weather pull

# %%
weather_client = get_weather_client()

# %%
weather_client

# %%
weather_df = fetch_weather(weather_client, start_date, end_date)

# %%
weather_df.head()
# Out:
#                            temperature
# date
# 2025-01-01 00:00:00+00:00      -0.1385
# 2025-01-01 01:00:00+00:00      -0.1385
# 2025-01-01 02:00:00+00:00      -0.1385
# 2025-01-01 03:00:00+00:00      -0.3885
# 2025-01-01 04:00:00+00:00      -0.2885

# %%
weather_df.size
# Out:
# 336

# %%
weatherbatch_df = fetch_weather_batches(weather_client, start_date, end_date)
# Out:
# Fetching weather 2025-01-01 to 2025-01-14...

# %%
load_client = get_load_client()

# %%
load_client
# Out:
# GridStatusClient(host=https://api.gridstatus.io/v1)

# %%
load_df = fetch_load(load_client)

# %% [markdown]
# ### Full Pull Test

# %%
from extract import fetch_all_data

# %%
df = fetch_all_data(start_date, end_date)
# Out:
# 2026-06-05 16:47:38 - INFO - Fetching Page 1...
# 2026-06-05 16:47:38 - INFO - GET https://api.gridstatus.io/v1/datasets/spp_load_hourly/query
# 2026-06-05 16:47:38 - INFO - Params: {'start_time': Timestamp('2025-01-01 00:00:00'), 'end_time': Timestamp('2025-01-08 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': None, 'cursor': '', 'filter_column': 'balancing_area_name', 'filter_value': 'SPP', 'filter_operator': '=', 'columns': 'interval_start_utc,balancing_area_name,control_zone_name,forecast_area_type,load', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# Fetching 2025-01-01 to 2025-01-08...
# 2026-06-05 16:47:39 - INFO - Done in 0.76 seconds.
# 2026-06-05 16:47:39 - INFO - Total number of rows: 3024
# 2026-06-05 16:47:39 - INFO - Fetching Page 1...
# 2026-06-05 16:47:39 - INFO - GET https://api.gridstatus.io/v1/datasets/spp_load_hourly/query
# 2026-06-05 16:47:39 - INFO - Params: {'start_time': Timestamp('2025-01-08 00:00:00'), 'end_time': Timestamp('2025-01-14 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': None, 'cursor': '', 'filter_column': 'balancing_area_name', 'filter_value': 'SPP', 'filter_operator': '=', 'columns': 'interval_start_utc,balancing_area_name,control_zone_name,forecast_area_type,load', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# Fetching 2025-01-08 to 2025-01-14...
# 2026-06-05 16:47:39 - INFO - Too Many Requests. Limit: 1 per 1 second.. Retrying in 1 seconds. Retry 1 of 3.
# 2026-06-05 16:47:42 - INFO - Done in 3.31 seconds.
# 2026-06-05 16:47:42 - INFO - Total number of rows: 2592
# Fetching weather 2025-01-01 to 2025-01-14...
